# %% [markdown]
# # Pancakes Lab 8
#
# * Adriano Ramón Hernández

# %%
import pydot
from collections import defaultdict 
from IPython.display import Image, display
import time

# %%
def lstr(p):
        return ''.join([str(elem)  for elem in p])

# %%
def ModifiedBFS(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
        flip = 0
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydot.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            
            if(s != sorted(s)):
              
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:] 
                if (d != s) and not(lstr(d) in visited.keys()):
                  if (d != sorted(d)):
                    node = pydot.Node(lstr(d))
                  else:
                        node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                    
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 

        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [1,3,2,4]
ModifiedBFS(p)

# %%
def ModifiedBFSPreSols(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                    node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [2,1,3]
ModifiedBFSPreSols(p)

# %%
def ModifiedBFSPreSolsLevel(s,L):  

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")

        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append([s,0]) 
        visited[lstr(s)] = True
        
        heigth=0
        while queue: 
  
            # Dequeue a vertex from queue 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if (s != sorted(s)) and (l < L):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if (d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append([d,l+1]) 
                  visited[lstr(d)] = True 
                  
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [4,3,2,1]
ModifiedBFSPreSolsLevel(p,3)

# %% [markdown]
# ## 1. Modify the PancakesTrees.ipynb code in your own to plot the Pancake Network and calculate Pn for small n‘s.

# %%
def pancakeNetwork(s): 
        '''
        Plot a pancake network
        modified of ModifiedBFSPreSols
        '''
        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="graph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 

            for i in range(len(s)-1):
              d = s[i+1::-1] + s[i+2:]  
              graph[lstr(s)].append(lstr(d))
              if (d != sorted(d)):
                node = pydot.Node(lstr(d))
              else:
                node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green  
              if not(lstr(d) in graph.keys()):
                G.add_node(node)
                edge = pydot.Edge(lstr(s),lstr(d))
                G.add_edge(edge)
                
              if not(lstr(d) in visited.keys()):
                queue.append(d) 
                visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %% [markdown]
# n = 1

# %%
m = [1]
tik = time.time()
pancakeNetwork(m)
tok = time.time()
print(1,"nodes, time:",tok-tik,"s")
# Out:
# 1 nodes, time: 0.020666837692260742 s

# %% [markdown]
# n = 2

# %%
m = [2,1]
tik = time.time()
pancakeNetwork(m)
tok = time.time()
print(2,"nodes, time:",tok-tik,"s")
# Out:
# 2 nodes, time: 0.07895612716674805 s

# %% [markdown]
# n = 3

# %%
m = [1,3,2]
tik = time.time()
pancakeNetwork(m)
tok = time.time()
print(3,"nodes, time:",tok-tik,"s")
# Out:
# 3 nodes, time: 0.03722524642944336 s

# %% [markdown]
# n = 4

# %%
m = [4,3,2,1]
tik = time.time()
pancakeNetwork(m)
tok = time.time()
print(4,"nodes, time:",tok-tik,"s")
# Out:
# 4 nodes, time: 0.0969381332397461 s

# %% [markdown]
# n = 5

# %%
m = [5,4,3,2,1]
tik = time.time()
pancakeNetwork(m)
tok = time.time()
print(5,"nodes, time:",tok-tik,"s")
# Out:
# 5 nodes, time: 0.7655022144317627 s

# %% [markdown]
# ## 2. Modify the PancakesTrees.ipynb code leaving only the necessary code and data structures required to calculate the Pn and run the code for at least one night (8 hours) starting with n=5. What is the largest Pn calculated? (Save the results in drive to avoid losing them)

# %%
def pancakes_pn(s):  
        n = len(s)
        # Create dictionaries graph,visited and pydot graph G
        visited = defaultdict()
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 

            node = pydot.Node(lstr(s))

            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if not(lstr(d) in visited.keys()):
                    queue.append([d,l+1]) 
                    visited[lstr(d)] = True 
              
        # Display P(n)
        print('P({}) = {}'.format(n, l))

# %%
n = 5
start_run = time.time()
while True:
    pancakes = list(range(1, n+1))
    start_time = time.time()
    pancakes_pn(pancakes)
    end_time = time.time()
    print("time:",end_time-start_time,"seconds")
    n = n + 1;
# Out:
# P(5) = 5
# time: 0.010500669479370117 seconds
# P(6) = 7
# time: 0.06568360328674316 seconds
# P(7) = 8
# time: 0.4436614513397217 seconds
# P(8) = 9
# time: 4.6917335987091064 seconds
# P(9) = 10
# time: 58.329367876052856 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-9ad85c7bb372> in <module>()
#       4     pancakes = list(range(1, n+1))
#       5     start_time = time.time()
# ----> 6     pancakes_pn(pancakes)
#       7     end_time = time.time()
#       8     print("time:",end_time-start_time,"seconds")
#
# <ipython-input-35-2ff3fb0ca7de> in pancakes_pn(s)
#      14
#      15             # Dequeue a vertex from queue
# ---> 16             e = queue.pop(0)
#      17             s = e[0]
#      18             l = e[1]
#
# KeyboardInterrupt:

# %%
end_run = time.time()
print((end_run-start_run)/60, "minutes")
# Out:
# 8.02316210269928 minutes

# %%
print((end_run-start_run)/60/60, "hours")
# Out:
# 0.13371936837832132 hours

# %% [markdown]
# ## 3. Modify the PancakesTrees.ipynb code to plot the pancakes trees using two spatulas.

# %%
def twospatulas(s,L):  

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            flag = False
            
            for i in list(range(len(s) - 1)):
              u = list(range(len(s) - (i + 1)))
              for j in u[::-1]:
                r = s[j:len(s) - i]
                d = s[0:j] + r[::-1] + s[len(s)-i:]
                if(d == sorted(d)):
                     flag = True
              if flag:
                node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
              else: 
                node = pydot.Node(lstr(s))

              G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)) and (l < L):
              for i in list(range(len(s) - 1)):
                u = list(range(len(s) - (i + 1)))
                for j in u[::-1]:
                  r = s[j:len(s) - i]
                  d = s[0:j] + r[::-1] + s[len(s)-i:]
                  if (d != s) and not(lstr(d) in visited.keys()):
                    if(d != sorted(d)):
                      node = pydot.Node(lstr(d))
                    else:
                      node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                    
                    G.add_node(node)
                    edge = pydot.Edge(lstr(s),lstr(d))
                    G.add_edge(edge)
                    graph[lstr(s)].append(lstr(d))
                    queue.append([d,l+1]) 
                    visited[lstr(d)] = True 
                
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [4,2,3,1]
twospatulas(p,2)

# %%
p = [3,2,1,4,5]
twospatulas(p,1)

# %% [markdown]
# ## References
#
# - Breadth First Search or BFS for a Graph https://www.geeksforgeeks.org/breadth-first-search-or-bfs-for-a-graph/
#
# - Graph visualization using Python https://www.youtube.com/watch?v=SpDI6-FvtJY
#
# - nikhilkumarsingh
# /
# PyDot-Examples https://github.com/nikhilkumarsingh/PyDot-Examples/blob/master/Directory_Structure_Plotter.ipynb
#
# - pydot https://pypi.org/project/pydot/
#
# - Graphviz https://www.graphviz.org/
#
# - NetworkX https://networkx.github.io/
